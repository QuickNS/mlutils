# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Prepare sample datasets

# %%
import pandas as pd

# loading a dataset
df = pd.read_csv('data/Train.csv', low_memory=False, nrows=1000, parse_dates=['saledate'])
df.head()

# creating a dataset with a few categorical values
df_c = pd.DataFrame(data=[[25,'New York','Medium'],
                        [35,'Seattle','Small'], 
                        [12,None,'Large'], 
                        [26, 'Paris',None],
                        [32, 'Seattle','X-Large']],
                  columns=['SomeNumber','City','Size'])

# creating a dataset with a couple of numerical columns
df_n = pd.DataFrame(data=[[12, 5000],
                         [2, 9234],
                         [56, np.nan],
                         [5, 22344],
                         [18, 9234]],
                   columns=['Age','SomeOtherNumber'])

# %% [markdown]
# ## Dataframes

# %%
from mlutils.dataframes import *

# %% [markdown]
# ### display_all

# %%
help(display_all)
# Out:
# Help on function display_all in module mlutils.dataframes:
#
# display_all(df: pandas.core.frame.DataFrame, transpose: bool = False)
#     Displays a DataFrame up to 1000x1000. Allows transposing

# %%
display_all(df.head(), transpose=True)
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                    66000
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                     3
# YearMade                                                      2004
# MachineHoursCurrentMeter                                        68
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# fiModelSeries                                                  NaN
# fiModelDescriptor                                              NaN
# ProductSize                                                    NaN
# fiProductClassDesc        Wheel Loader - 110.0 to 120.0 Horsepower
# state                                                      Alabama
# ProductGroup                                                    WL
# ProductGroupDesc                                      Wheel Loader
# Drive_System                                                   NaN
# Enclosure                                               EROPS w AC
# Forks                                          None or Unspecified
# Pad_Type                                                       NaN
# Ride_Control                                   None or Unspecified
# Stick                                                          NaN
# Transmission                                                   NaN
# Turbocharged                                                   NaN
# Blade_Extension                                                NaN
# Blade_Width                                                    NaN
# Enclosure_Type                                                 NaN
# Engine_Horsepower                                              NaN
# Hydraulics                                                 2 Valve
# Pushblock                                                      NaN
# Ripper                                                         NaN
# Scarifier                                                      NaN
# Tip_Control                                                    NaN
# Tire_Size                                      None or Unspecified
# Coupler                                        None or Unspecified
# Coupler_System                                                 NaN
# Grouser_Tracks                                                 NaN
# Hydraulics_Flow                                                NaN
# Track_Type                                                     NaN
# Undercarriage_Pad_Width                                        NaN
# Stick_Length                                                   NaN
# Thumb                                                          NaN
# Pattern_Changer                                                NaN
# Grouser_Type                                                   NaN
# Backhoe_Mounting                                               NaN
# Blade_Type                                                     NaN
# Travel_Controls                                                NaN
# Differential_Type                                         Standard
# Steering_Controls                                     Conventional
#
#                                                                  1  \
# SalesID                                                    1139248
# SalePrice                                                    57000
# MachineID                                                   117657
# ModelID                                                         77
# datasource                                                     121
# auctioneerID                                                     3
# YearMade                                                      1996
# MachineHoursCurrentMeter                                      4640
# UsageBand                                                      Low
# saledate                                       2004-03-26 00:00:00
# fiModelDesc                                                 950FII
# fiBaseModel                                                    950
# fiSecondaryDesc                                                  F
# fiModelSeries                                                   II
# fiModelDescriptor                                              NaN
# ProductSize                                                 Medium
# fiProductClassDesc        Wheel Loader - 150.0 to 175.0 Horsepower
# state                                               North Carolina
# ProductGroup                                                    WL
# ProductGroupDesc                                      Wheel Loader
# Drive_System                                                   NaN
# Enclosure                                               EROPS w AC
# Forks                                          None or Unspecified
# Pad_Type                                                       NaN
# Ride_Control                                   None or Unspecified
# Stick                                                          NaN
# Transmission                                                   NaN
# Turbocharged                                                   NaN
# Blade_Extension                                                NaN
# Blade_Width                                                    NaN
# Enclosure_Type                                                 NaN
# Engine_Horsepower                                              NaN
# Hydraulics                                                 2 Valve
# Pushblock                                                      NaN
# Ripper                                                         NaN
# Scarifier                                                      NaN
# Tip_Control                                                    NaN
# Tire_Size                                                     23.5
# Coupler                                        None or Unspecified
# Coupler_System                                                 NaN
# Grouser_Tracks                                                 NaN
# Hydraulics_Flow                                                NaN
# Track_Type                                                     NaN
# Undercarriage_Pad_Width                                        NaN
# Stick_Length                                                   NaN
# Thumb                                                          NaN
# Pattern_Changer                                                NaN
# Grouser_Type                                                   NaN
# Backhoe_Mounting                                               NaN
# Blade_Type                                                     NaN
# Travel_Controls                                                NaN
# Differential_Type                                         Standard
# Steering_Controls                                     Conventional
#
#                                                                           2  \
# SalesID                                                             1139249
# SalePrice                                                             10000
# MachineID                                                            434808
# ModelID                                                                7009
# datasource                                                              121
# auctioneerID                                                              3
# YearMade                                                               2001
# MachineHoursCurrentMeter                                               2838
# UsageBand                                                              High
# saledate                                                2004-02-26 00:00:00
# fiModelDesc                                                             226
# fiBaseModel                                                             226
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...
# state                                                              New York
# ProductGroup                                                            SSL
# ProductGroupDesc                                         Skid Steer Loaders
# Drive_System                                                            NaN
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                        Auxiliary
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                          None or Unspecified
# Grouser_Tracks                                          None or Unspecified
# Hydraulics_Flow                                                    Standard
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                           3  \
# SalesID                                                             1139251
# SalePrice                                                             38500
# MachineID                                                           1026470
# ModelID                                                                 332
# datasource                                                              121
# auctioneerID                                                              3
# YearMade                                                               2001
# MachineHoursCurrentMeter                                               3486
# UsageBand                                                              High
# saledate                                                2011-05-19 00:00:00
# fiModelDesc                                                        PC120-6E
# fiBaseModel                                                           PC120
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           -6E
# fiModelDescriptor                                                       NaN
# ProductSize                                                           Small
# fiProductClassDesc        Hydraulic Excavator, Track - 12.0 to 14.0 Metr...
# state                                                                 Texas
# ProductGroup                                                            TEX
# ProductGroupDesc                                           Track Excavators
# Drive_System                                                            NaN
# Enclosure                                                        EROPS w AC
# Forks                                                                   NaN
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                          2 Valve
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                           4
# SalesID                                                             1139253
# SalePrice                                                             11000
# MachineID                                                           1057373
# ModelID                                                               17311
# datasource                                                              121
# auctioneerID                                                              3
# YearMade                                                               2007
# MachineHoursCurrentMeter                                                722
# UsageBand                                                            Medium
# saledate                                                2009-07-23 00:00:00
# fiModelDesc                                                            S175
# fiBaseModel                                                            S175
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...
# state                                                              New York
# ProductGroup                                                            SSL
# ProductGroupDesc                                         Skid Steer Loaders
# Drive_System                                                            NaN
# Enclosure                                                             EROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Blade_Extension                                                         NaN
# Blade_Width                                                             NaN
# Enclosure_Type                                                          NaN
# Engine_Horsepower                                                       NaN
# Hydraulics                                                        Auxiliary
# Pushblock                                                               NaN
# Ripper                                                                  NaN
# Scarifier                                                               NaN
# Tip_Control                                                             NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                          None or Unspecified
# Grouser_Tracks                                          None or Unspecified
# Hydraulics_Flow                                                    Standard
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN

# %% [markdown]
# ### summarize

# %%
help(summarize)
# Out:
# Help on function summarize in module mlutils.dataframes:
#
# summarize(df: pandas.core.frame.DataFrame, transpose: bool = False)
#     Displays extended summary statistics of a pandas dataframe object

# %%
summarize(df)
# Out:
#                   SalesID SalePrice    MachineID  ModelID datasource  \
# count                1000      1000         1000     1000       1000
# mean          1.14089e+06   33199.9       855034  7951.05        121
# std               958.539   24318.8       309141  7310.69          0
# min           1.13925e+06      4750         4527       43        121
# 25%           1.14007e+06     14500       752606  3356.75        121
# 50%           1.14091e+06     26500  1.01692e+06     4754        121
# 75%           1.14169e+06     44000  1.04631e+06    10569        121
# max           1.14258e+06    141000  1.06973e+06    36540        121
# counts               1000      1000         1000     1000       1000
# uniques              1000       169          999      540          1
# missing                 0         0            0        0          0
# missing_perc           0%        0%           0%       0%         0%
# types             numeric   numeric      numeric  numeric   constant
#
#              auctioneerID YearMade MachineHoursCurrentMeter    UsageBand  \
# count                1000     1000                     1000          NaN
# mean                    3  1866.88                  4191.14          NaN
# std                     0  339.744                  5177.54          NaN
# min                     3     1000                        0          NaN
# 25%                     3     1995                   781.25          NaN
# 50%                     3     2000                     2374          NaN
# 75%                     3     2004                  5860.25          NaN
# max                     3     2008                    37796          NaN
# counts               1000     1000                     1000          869
# uniques                 1       40                      839            3
# missing                 0        0                        0          131
# missing_perc           0%       0%                       0%       13.10%
# types            constant  numeric                  numeric  categorical
#
#              saledate  fiModelDesc  fiBaseModel fiSecondaryDesc fiModelSeries  \
# count             NaN          NaN          NaN             NaN           NaN
# mean              NaN          NaN          NaN             NaN           NaN
# std               NaN          NaN          NaN             NaN           NaN
# min               NaN          NaN          NaN             NaN           NaN
# 25%               NaN          NaN          NaN             NaN           NaN
# 50%               NaN          NaN          NaN             NaN           NaN
# 75%               NaN          NaN          NaN             NaN           NaN
# max               NaN          NaN          NaN             NaN           NaN
# counts           1000         1000         1000             651           137
# uniques           227          538          308              49            30
# missing             0            0            0             349           863
# missing_perc       0%           0%           0%          34.90%        86.30%
# types            date  categorical  categorical     categorical   categorical
#
#              fiModelDescriptor  ProductSize fiProductClassDesc        state  \
# count                      NaN          NaN                NaN          NaN
# mean                       NaN          NaN                NaN          NaN
# std                        NaN          NaN                NaN          NaN
# min                        NaN          NaN                NaN          NaN
# 25%                        NaN          NaN                NaN          NaN
# 50%                        NaN          NaN                NaN          NaN
# 75%                        NaN          NaN                NaN          NaN
# max                        NaN          NaN                NaN          NaN
# counts                     235          463               1000         1000
# uniques                     24            6                 62           48
# missing                    765          537                  0            0
# missing_perc            76.50%       53.70%                 0%           0%
# types              categorical  categorical        categorical  categorical
#
#              ProductGroup ProductGroupDesc Drive_System    Enclosure   Forks  \
# count                 NaN              NaN          NaN          NaN     NaN
# mean                  NaN              NaN          NaN          NaN     NaN
# std                   NaN              NaN          NaN          NaN     NaN
# min                   NaN              NaN          NaN          NaN     NaN
# 25%                   NaN              NaN          NaN          NaN     NaN
# 50%                   NaN              NaN          NaN          NaN     NaN
# 75%                   NaN              NaN          NaN          NaN     NaN
# max                   NaN              NaN          NaN          NaN     NaN
# counts               1000             1000          219          999     505
# uniques                 6                6            4            3       2
# missing                 0                0          781            1     495
# missing_perc           0%               0%       78.10%        0.10%  49.50%
# types         categorical      categorical  categorical  categorical    bool
#
#                  Pad_Type Ride_Control Stick Transmission Turbocharged  \
# count                 NaN          NaN   NaN          NaN          NaN
# mean                  NaN          NaN   NaN          NaN          NaN
# std                   NaN          NaN   NaN          NaN          NaN
# min                   NaN          NaN   NaN          NaN          NaN
# 25%                   NaN          NaN   NaN          NaN          NaN
# 50%                   NaN          NaN   NaN          NaN          NaN
# 75%                   NaN          NaN   NaN          NaN          NaN
# max                   NaN          NaN   NaN          NaN          NaN
# counts                160          332   160          392          160
# uniques                 3            3     2            6            2
# missing               840          668   840          608          840
# missing_perc          84%       66.80%   84%       60.80%          84%
# types         categorical  categorical  bool  categorical         bool
#
#              Blade_Extension  Blade_Width Enclosure_Type Engine_Horsepower  \
# count                    NaN          NaN            NaN               NaN
# mean                     NaN          NaN            NaN               NaN
# std                      NaN          NaN            NaN               NaN
# min                      NaN          NaN            NaN               NaN
# 25%                      NaN          NaN            NaN               NaN
# 50%                      NaN          NaN            NaN               NaN
# 75%                      NaN          NaN            NaN               NaN
# max                      NaN          NaN            NaN               NaN
# counts                    59           59             59                59
# uniques                    2            4              3                 2
# missing                  941          941            941               941
# missing_perc          94.10%       94.10%         94.10%            94.10%
# types                   bool  categorical    categorical              bool
#
#                Hydraulics Pushblock       Ripper Scarifier  Tip_Control  \
# count                 NaN       NaN          NaN       NaN          NaN
# mean                  NaN       NaN          NaN       NaN          NaN
# std                   NaN       NaN          NaN       NaN          NaN
# min                   NaN       NaN          NaN       NaN          NaN
# 25%                   NaN       NaN          NaN       NaN          NaN
# 50%                   NaN       NaN          NaN       NaN          NaN
# 75%                   NaN       NaN          NaN       NaN          NaN
# max                   NaN       NaN          NaN       NaN          NaN
# counts                838        59          231        59           59
# uniques                 9         2            4         2            3
# missing               162       941          769       941          941
# missing_perc       16.20%    94.10%       76.90%    94.10%       94.10%
# types         categorical      bool  categorical      bool  categorical
#
#                 Tire_Size      Coupler Coupler_System Grouser_Tracks  \
# count                 NaN          NaN            NaN            NaN
# mean                  NaN          NaN            NaN            NaN
# std                   NaN          NaN            NaN            NaN
# min                   NaN          NaN            NaN            NaN
# 25%                   NaN          NaN            NaN            NaN
# 50%                   NaN          NaN            NaN            NaN
# 75%                   NaN          NaN            NaN            NaN
# max                   NaN          NaN            NaN            NaN
# counts                231          601            174            173
# uniques                11            3              2              2
# missing               769          399            826            827
# missing_perc       76.90%       39.90%         82.60%         82.70%
# types         categorical  categorical           bool           bool
#
#              Hydraulics_Flow Track_Type Undercarriage_Pad_Width Stick_Length  \
# count                    NaN        NaN                     NaN          NaN
# mean                     NaN        NaN                     NaN          NaN
# std                      NaN        NaN                     NaN          NaN
# min                      NaN        NaN                     NaN          NaN
# 25%                      NaN        NaN                     NaN          NaN
# 50%                      NaN        NaN                     NaN          NaN
# 75%                      NaN        NaN                     NaN          NaN
# max                      NaN        NaN                     NaN          NaN
# counts                   173        253                     256          253
# uniques                    2          2                      12           14
# missing                  827        747                     744          747
# missing_perc          82.70%     74.70%                  74.40%       74.70%
# types                   bool       bool             categorical  categorical
#
#                     Thumb Pattern_Changer Grouser_Type Backhoe_Mounting  \
# count                 NaN             NaN          NaN              NaN
# mean                  NaN             NaN          NaN              NaN
# std                   NaN             NaN          NaN              NaN
# min                   NaN             NaN          NaN              NaN
# 25%                   NaN             NaN          NaN              NaN
# 50%                   NaN             NaN          NaN              NaN
# 75%                   NaN             NaN          NaN              NaN
# max                   NaN             NaN          NaN              NaN
# counts                253             253          253              171
# uniques                 3               2            2                1
# missing               747             747          747              829
# missing_perc       74.70%          74.70%       74.70%           82.90%
# types         categorical            bool         bool         constant
#
#                Blade_Type Travel_Controls Differential_Type Steering_Controls
# count                 NaN             NaN               NaN               NaN
# mean                  NaN             NaN               NaN               NaN
# std                   NaN             NaN               NaN               NaN
# min                   NaN             NaN               NaN               NaN
# 25%                   NaN             NaN               NaN               NaN
# 50%                   NaN             NaN               NaN               NaN
# 75%                   NaN             NaN               NaN               NaN
# max                   NaN             NaN               NaN               NaN
# counts                173             172               172               172
# uniques                 7               6                 2                 2
# missing               827             828               828               828
# missing_perc       82.70%          82.80%            82.80%            82.80%
# types         categorical     categorical              bool              bool

# %% [markdown]
# ### display_mem_usage

# %%
help(display_mem_usage)
# Out:
# Help on function display_mem_usage in module mlutils.dataframes:
#
# display_mem_usage(df)
#     Displays memory utilization of a pandas dataframe object

# %%
display_mem_usage(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 53 columns):
# SalesID                     1000 non-null int64
# SalePrice                   1000 non-null int64
# MachineID                   1000 non-null int64
# ModelID                     1000 non-null int64
# datasource                  1000 non-null int64
# auctioneerID                1000 non-null int64
# YearMade                    1000 non-null int64
# MachineHoursCurrentMeter    1000 non-null int64
# UsageBand                   869 non-null object
# saledate                    1000 non-null datetime64[ns]
# fiModelDesc                 1000 non-null object
# fiBaseModel                 1000 non-null object
# fiSecondaryDesc             651 non-null object
# fiModelSeries               137 non-null object
# fiModelDescriptor           235 non-null object
# ProductSize                 463 non-null object
# fiProductClassDesc          1000 non-null object
# state                       1000 non-null object
# ProductGroup                1000 non-null object
# ProductGroupDesc            1000 non-null object
# Drive_System                219 non-null object
# Enclosure                   999 non-null object
# Forks                       505 non-null object
# Pad_Type                    160 non-null object
# Ride_Control                332 non-null object
# Stick                       160 non-null object
# Transmission                392 non-null object
# Turbocharged                160 non-null object
# Blade_Extension             59 non-null object
# Blade_Width                 59 non-null object
# Enclosure_Type              59 non-null object
# Engine_Horsepower           59 non-null object
# Hydraulics                  838 non-null object
# Pushblock                   59 non-null object
# Ripper                      231 non-null object
# Scarifier                   59 non-null object
# Tip_Control                 59 non-null object
# Tire_Size                   231 non-null object
# Coupler                     601 non-null object
# Coupler_System              174 non-null object
# Grouser_Tracks              173 non-null object
# Hydraulics_Flow             173 non-null object
# Track_Type                  253 non-null object
# Undercarriage_Pad_Width     256 non-null object
# Stick_Length                253 non-null object
# Thumb                       253 non-null object
# Pattern_Changer             253 non-null object
# Grouser_Type                253 non-null object
# Backhoe_Mounting            171 non-null object
# Blade_Type                  173 non-null object
# Travel_Controls             172 non-null object
# Differential_Type           172 non-null object
# Steering_Controls           172 non-null object
# dtypes: datetime64[ns](1), int64(8), object(44)
# memory usage: 2.0 MB
# None
#
# Total memory usage for float columns: 0.00 MB
# Total memory usage for int columns: 0.06 MB
# Total memory usage for object columns: 1.92 MB
# Total memory usage for bool columns: 0.00 MB
# Total memory usage for category columns: 0.00 MB
#
# Average memory usage for float columns: 0.00 MB
# Average memory usage for int columns: 0.01 MB
# Average memory usage for object columns: 0.04 MB
# Average memory usage for bool columns: 0.00 MB
# Average memory usage for category columns: 0.00 MB

# %% [markdown]
# ### detect_missing

# %%
help(detect_missing)
# Out:
# Help on function detect_missing in module mlutils.dataframes:
#
# detect_missing(data: pandas.core.frame.DataFrame)
#     Prints number of missing values on each column. Alternatively, can display percentages

# %%
detect_missing(df)
# Out:
#                          Total  Percent
# Blade_Extension            941    0.941
# Blade_Width                941    0.941
# Enclosure_Type             941    0.941
# Engine_Horsepower          941    0.941
# Pushblock                  941    0.941
# Scarifier                  941    0.941
# Tip_Control                941    0.941
# fiModelSeries              863    0.863
# Pad_Type                   840    0.840
# Stick                      840    0.840
# Turbocharged               840    0.840
# Backhoe_Mounting           829    0.829
# Differential_Type          828    0.828
# Steering_Controls          828    0.828
# Travel_Controls            828    0.828
# Grouser_Tracks             827    0.827
# Hydraulics_Flow            827    0.827
# Blade_Type                 827    0.827
# Coupler_System             826    0.826
# Drive_System               781    0.781
# Ripper                     769    0.769
# Tire_Size                  769    0.769
# fiModelDescriptor          765    0.765
# Track_Type                 747    0.747
# Stick_Length               747    0.747
# Thumb                      747    0.747
# Pattern_Changer            747    0.747
# Grouser_Type               747    0.747
# Undercarriage_Pad_Width    744    0.744
# Ride_Control               668    0.668
# Transmission               608    0.608
# ProductSize                537    0.537
# Forks                      495    0.495
# Coupler                    399    0.399
# fiSecondaryDesc            349    0.349
# Hydraulics                 162    0.162
# UsageBand                  131    0.131
# Enclosure                    1    0.001

# %% [markdown]
# ### detect_outliers

# %%
help(detect_outliers)
# Out:
# Help on function detect_outliers in module mlutils.dataframes:
#
# detect_outliers(x: pandas.core.series.Series, limits: tuple = None)
#     Returns indexes of outlier values in a numeric series. Can pass in lower and upper bounds using a tuple. If missing, the lower and upper bounds are set using interquantile range.
#
#     Example:
#         detect_outliers(df[column])
#         detect_outliers(df[column], (0, 5000))

# %%
outliers = detect_outliers(df.SalePrice)

temp = df.drop(outliers)
summarize(temp[['SalePrice']])
# Out:
# Number of outliers found: 42, using interval (-29750.0,88250.0)
#              SalePrice
# count              958
# mean           30105.8
# std            19551.9
# min               4750
# 25%              14000
# 50%              25500
# 75%              41000
# max              88000
# counts             958
# uniques            145
# missing              0
# missing_perc        0%
# types          numeric

# %%
outliers = detect_outliers(df.SalePrice, limits=(10000, 50000))

temp = df.drop(outliers)
summarize(temp[['SalePrice']])
# Out:
# Number of outliers found: 274, using interval (10000,50000)
#              SalePrice
# count              726
# mean           25132.4
# std            11348.2
# min              10000
# 25%              15000
# 50%              23500
# 75%              33875
# max              50000
# counts             726
# uniques             80
# missing              0
# missing_perc        0%
# types          numeric

# %% [markdown]
# ### split_dataset

# %%
help(split_dataset)
# Out:
# Help on function split_dataset in module mlutils.dataframes:
#
# split_dataset(df: pandas.core.frame.DataFrame, n: int = None, shuffle=False, random_seed=None)
#     Splits a DataFrame in a length n training dataset and a validation set with the remainder.
#     If n is None, automatically uses a 80/20 split.
#     By default keeps the dataset in order, but shuffle can be set to True to target a random sample for each dataset (without repetition).
#     A seed can also be supplied for consistency

# %%
print(f"Total size of dataset: {len(df)}")

df_train, df_val = split_dataset(df, 400000)
print(f"Training dataset: {len(df_train)}")
print(f"Validation dataset: {len(df_val)}")
# Out:
# Total size of dataset: 1000
# Training dataset: 1000
# Validation dataset: 0

# %%
# not supplying n parameter (does 80/20 split)
print(f"Total size of dataset: {len(df)}")

df_train, df_val = split_dataset(df)
print(f"Training dataset: {len(df_train)}")
print(f"Validation dataset: {len(df_val)}")
# Out:
# Total size of dataset: 1000
# Training dataset: 800
# Validation dataset: 200

# %%
# splitting, with random shuffle and seed
df_train, df_val = split_dataset(df, shuffle=True, random_seed=4)
print(f"Training dataset: {len(df_train)}")
print(f"Validation dataset: {len(df_val)}")
print(f"First items in training dataset: {df_train.head().index.values}")
# Out:
# Training dataset: 800
# Validation dataset: 200
# First items in training dataset: [456 709 673 756 600]

# %% [markdown]
# ### analyze_redundant_features

# %%
help(analyze_redundant_features)
# Out:
# Help on function analyze_redundant_features in module mlutils.dataframes:
#
# analyze_redundant_features(df, threshold=0.1, no_plot=False)

# %%
import seaborn as sns
sns.set()
sns.set_style('whitegrid')
sns.set_palette('Dark2')

to_keep = ['YearMade', 'Coupler_System', 'ProductSize', 'fiProductClassDesc',
       , 'saleElapsed', 'Hydraulics_Flow', 'Grouser_Tracks',
       'fiSecondaryDesc', 'fiModelDesc', 'Enclosure',
       'fiBaseModel', 'fiModelDescriptor', 'saleYear', 'MachineID',
       'Hydraulics', 'ProductGroupDesc', 'saleDayofyear', 'Drive_System',
       'Tire_Size', 'saleDay']

temp = df[to_keep]
create_categories(temp)
proc_df, label, na_dict = process_dataframe(temp)

clusters, groups = analyze_redundant_features(proc_df, 0.3)

# %%
clusters
# Out:
#                             a                 b  distance
# cluster
# cluster_0         fiModelDesc       fiBaseModel   0.00020
# cluster_1     Hydraulics_Flow    Grouser_Tracks   0.00270
# cluster_2      Coupler_System         cluster_1   0.00775
# cluster_3         saleElapsed          saleYear   0.01170
# cluster_4  fiProductClassDesc  ProductGroupDesc   0.19970

# %%
groups
# Out:
# array([list(['fiModelDesc', 'fiBaseModel']),
#        list(['Hydraulics_Flow', 'Grouser_Tracks', 'Coupler_System']),
#        list(['saleElapsed', 'saleYear']),
#        list(['fiProductClassDesc', 'ProductGroupDesc'])], dtype=object)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### create_categories

# %%
from mlutils.preprocessing import *

print(df_c.dtypes)
df_c.head()
# Out:
# SomeNumber     int64
# City          object
# Size          object
# dtype: object
#    SomeNumber      City     Size
# 0          25  New York   Medium
# 1          35   Seattle    Small
# 2          12      None    Large
# 3          26     Paris     None
# 4          32   Seattle  X-Large

# %%
help(create_categories)
# Out:
# Help on function create_categories in module mlutils.preprocessing:
#
# create_categories(df: pandas.core.frame.DataFrame, columns=None)
#     Change any columns of strings in a panda's dataframe to a column of
#     categorical values. This applies the changes inplace. Optionally, we can pass a list of columns to be changed.
#
#     Parameters:
#     -----------
#     df: A pandas dataframe to apply changes to.
#
#     columns: a list of columns. If none specified all string columns will be changed to categorical values

# %%
temp = df_c.copy()
create_categories(temp)
temp.dtypes
# Out:
# SomeNumber       int64
# City          category
# Size          category
# dtype: object

# %%
# -1 stands for missing values
temp.Size.cat.codes.value_counts()
# Out:
#  3    1
# -1    1
#  2    1
#  1    1
#  0    1
# dtype: int64

# %%
temp.Size.cat.categories
# Out:
# Index(['Large', 'Medium', 'Small', 'X-Large'], dtype='object')

# %% [markdown]
# ### apply_categories

# %%
help(apply_categories)
# Out:
# Help on function apply_categories in module mlutils.preprocessing:
#
# apply_categories(df, trn)
#     Changes any columns of strings in df into categorical variables using trn as
#     a template for the category codes.
#
#     Parameters:
#     -----------
#     df: A pandas dataframe. Any columns of strings will be changed to
#         categorical values. The category codes are determined by trn.
#
#     trn: A pandas dataframe. When creating a category for df, it looks up the
#         what the category's code were in trn and makes those the category codes
#         for df.

# %%
df_test = pd.DataFrame(data=[[25,'New York','Large'],
                        [35,'New York','Medium'], 
                        [12,'Seattle','Medium'], 
                        [26, 'Seattle','Small'],
                        [27, 'Lisbon','Large']], # city not present in training dataset
                  columns=['SomeNumber','City','Size'])
df_test
# Out:
#    SomeNumber      City    Size
# 0          25  New York   Large
# 1          35  New York  Medium
# 2          12   Seattle  Medium
# 3          26   Seattle   Small
# 4          27    Lisbon   Large

# %%
apply_categories(df_test, temp)

# %%
df_test.dtypes
# Out:
# SomeNumber       int64
# City          category
# Size          category
# dtype: object

# %% [markdown]
# ### add_date_features

# %%
df.head().saledate
# Out:
# 0   2006-11-16
# 1   2004-03-26
# 2   2004-02-26
# 3   2011-05-19
# 4   2009-07-23
# Name: saledate, dtype: datetime64[ns]

# %%
help(add_date_features)
# Out:
# Help on function add_date_features in module mlutils.preprocessing:
#
# add_date_features(df, fldname, drop=True, time=False)
#     add_date_features converts a column of df from a datetime64 to many columns containing
#     the information from the date. This applies changes inplace.
#
#     Parameters:
#     -----------
#     df: A pandas data frame. df gain several new columns.
#     fldname: A string that is the name of the date column you wish to expand.
#         If it is not a datetime64 series, it will be converted to one with pd.to_datetime.
#     drop: If true then the original date column will be removed.
#     time: If true time features: Hour, Minute, Second will be added.

# %%
add_date_features(df, 'saledate')

# %%
# by default it adds 13 columns to the end of the dataframe with the extracted date information
df.columns[-13:]
# Out:
# Index(['saleYear', 'saleMonth', 'saleWeek', 'saleDay', 'saleDayofweek',
#        'saleDayofyear', 'saleIs_month_end', 'saleIs_month_start',
#        'saleIs_quarter_end', 'saleIs_quarter_start', 'saleIs_year_end',
#        'saleIs_year_start', 'saleElapsed'],
#       dtype='object')

# %% [markdown]
# ### get_cardinality

# %%
help(get_cardinality)
# Out:
# Help on function get_cardinality in module mlutils.preprocessing:
#
# get_cardinality(df)
#     Returns the number of categories in each categorical feature. Very high cardinality might indicate it's better to use other alternatives like mean encodings

# %%
temp = df_c.copy()
create_categories(temp)

# %%
get_cardinality(temp)
# Out:
#   column  cardinality
# 1   Size            4
# 0   City            3

# %% [markdown]
# ### numericalize

# %%
help(numericalize)
# Out:
# Help on function numericalize in module mlutils.preprocessing:
#
# numericalize(df, max_n_cat=None)
#     Changes the column col from a categorical type to it's integer codes.
#
#     Parameters:
#     -----------
#     df: A pandas dataframe. df[name] will be filled with the integer codes from
#         col.
#
#     max_n_cat: If number of distinct values on a categorical column is higher than max_n_cat it will convert it to its integer codes. If max_n_cat is None, then all categorical columns will be converted

# %%
converted = temp.copy()
numericalize(converted, max_n_cat=1)
converted
# Out:
#    SomeNumber  City  Size
# 0          25     1     2
# 1          35     3     3
# 2          12     0     1
# 3          26     2     0
# 4          32     3     4

# %%
converted = temp.copy()
numericalize(converted, max_n_cat=3)
converted
# Out:
#    SomeNumber      City  Size
# 0          25  New York     2
# 1          35   Seattle     3
# 2          12       NaN     1
# 3          26     Paris     0
# 4          32   Seattle     4

# %% [markdown]
# ### one_hot_encode

# %%
help(one_hot_encode)
# Out:
# Help on function one_hot_encode in module mlutils.preprocessing:
#
# one_hot_encode(df: pandas.core.frame.DataFrame)
#     Returns a new dataframe with all categorical columns transformed using one-hot-encoding

# %%
temp = df_c.copy()
create_categories(temp)
temp.dtypes
# Out:
# SomeNumber       int64
# City          category
# Size          category
# dtype: object

# %%
encoded = one_hot_encode(temp)
encoded
# Out:
#    SomeNumber  City_New York  City_Paris  City_Seattle  Size_Large  \
# 0          25              1           0             0           0
# 1          35              0           0             1           0
# 2          12              0           0             0           1
# 3          26              0           1             0           0
# 4          32              0           0             1           0
#
#    Size_Medium  Size_Small  Size_X-Large
# 0            1           0             0
# 1            0           1             0
# 2            0           0             0
# 3            0           0             0
# 4            0           0             1

# %% [markdown]
# ### scale_vars

# %%
help(scale_vars)
# Out:
# Help on function scale_vars in module mlutils.preprocessing:
#
# scale_vars(df, mapper=None)
#     Applies standard scaling in all numerical columns optionally using an existing mapper.
#     Changed are applied in-place. Returns a mapper for future use.

# %%
df_n
# Out:
#    Age  SomeOtherNumber
# 0   12           5000.0
# 1    2           9234.0
# 2   56              NaN
# 3    5          22344.0
# 4   18           9234.0

# %%
# standard scaling
temp = df_n.copy()
mapper = scale_vars(temp)
temp
# Out:
#         Age  SomeOtherNumber
# 0 -0.338288        -0.989545
# 1 -0.850846        -0.340276
# 2  1.916966              NaN
# 3 -0.697079         1.670097
# 4 -0.030753        -0.340276

# %%
# applying same scaling to test dataset

df_new = pd.DataFrame(data=[[20, 1000],
                         [15, 9234]],
                   columns=['Age','SomeOtherNumber'])

scale_vars(df_new, mapper)

df_new
# Out:
#         Age  SomeOtherNumber
# 0  0.071758        -1.602931
# 1 -0.184521        -0.340276

# %% [markdown]
# ### fix_missing

# %%
help(fix_missing)
# Out:
# Help on function fix_missing in module mlutils.preprocessing:
#
# fix_missing(df, na_dict=None)
#     Fill missing data in all numerical columns of df with the median or a previously stored value through the na_dict, and add a {name}_na column
#     which specifies if the data was missing. Returns the na_dict for future use.

# %%
temp = df_n.copy()
na_dict = fix_missing(temp)
print(na_dict)
temp
# Out:
# {'SomeOtherNumber': 9234.0}
#    Age  SomeOtherNumber  SomeOtherNumber_na
# 0   12           5000.0               False
# 1    2           9234.0               False
# 2   56           9234.0                True
# 3    5          22344.0               False
# 4   18           9234.0               False

# %%
# applying same mapping to test dataset

df_new = pd.DataFrame(data=[[65, np.nan],
                         [np.nan, 2224]],
                   columns=['Age','SomeNumber'])

new_dict = fix_missing(df_new, na_dict)

print(new_dict)

df_new
# Out:
# {'SomeOtherNumber': 9234.0}
#     Age  SomeNumber
# 0  65.0      2224.0
# 1  65.0      2224.0

# %% [markdown]
# ### process_dataframe

# %%
temp = pd.concat((df_c, df_n), axis=1)
temp['Label'] = random.sample(range(1, 100), 5)
temp
# Out:
#    SomeNumber      City     Size  Age  SomeOtherNumber  Label
# 0          25  New York   Medium   12           5000.0     13
# 1          35   Seattle    Small    2           9234.0     40
# 2          12      None    Large   56              NaN      5
# 3          26     Paris     None    5          22344.0     67
# 4          32   Seattle  X-Large   18           9234.0      1

# %%
help(process_dataframe)
# Out:
# Help on function process_dataframe in module mlutils.preprocessing:
#
# process_dataframe(df, y_fld=None, drop_flds=None, ignore_flds=None, do_scale=False, mapper=None, na_dict=None, max_n_cat=None, subset=None)
#     All-in-one method to prepare a dataset for modeling. The following steps are taken:
#
#     if subset value is set, applies all operations on a randomly chosen sample of size=subset
#
#     Fixes missing values (by calling the fix_missing function) and optionally passing a na_dict created before
#
#     Applies standard scaling to all numerical values (by using the scale_vars function), optionally using a mapper
#
#     Numericalizes all categorical columns that have cardinality higher than max_n_cat (or all if not specified)
#
#     One-Hot encodes all remaining non-numerical features
#
#     Parameters:
#     -----------
#     df: A pandas dataframe.
#
#     y_fld: The label column (if any, leave None if not in df)
#
#     drop_flds: a collection of columns to be dropped from the dataset
#
#     ignore_flds: a collection of columns to remain unchanged during processing
#
#     do_scale: if the function should perform standard scaling on numeric features
#
#     na_dict: a dictionary of na replacements, created by this function or fix_missing function
#
#     max_n_cat: the maximum cardinality of features for one-hot-encoding. All above will be replace by int values
#
#     subset: the size of a randomly chosen subset of the original dataset to perform operations
#
#     mapper: a mapping of scaling operations, created by this function or the scale_vars function

# %%
create_categories(temp)
proc_df, label, na_dict, mapper = process_dataframe(temp, y_fld='Label', do_scale=True, max_n_cat=3)

# %%
proc_df
# Out:
#    SomeNumber  Size       Age  SomeOtherNumber  SomeOtherNumber_na  \
# 0   -0.126189     2 -0.338288        -1.018531                -0.5
# 1    1.135698     3 -0.850846        -0.300888                -0.5
# 2   -1.766641     1  1.916966        -0.300888                 2.0
# 3    0.000000     0 -0.697079         1.921196                -0.5
# 4    0.757132     4 -0.030753        -0.300888                -0.5
#
#    City_New York  City_Paris  City_Seattle  City_nan
# 0              1           0             0         0
# 1              0           0             1         0
# 2              0           0             0         1
# 3              0           1             0         0
# 4              0           0             1         0

# %%
label, na_dict, mapper
# Out:
# (array([13, 40,  5, 67,  1]),
#  {'SomeOtherNumber': 9234.0},
#  DataFrameMapper(default=False, df_out=False,
#          features=[(['SomeNumber'], StandardScaler(copy=True, with_mean=True, with_std=True)), (['Age'], StandardScaler(copy=True, with_mean=True, with_std=True)), (['SomeOtherNumber'], StandardScaler(copy=True, with_mean=True, with_std=True)), (['SomeOtherNumber_na'], StandardScaler(copy=True, with_mean=True, with_std=True))],
#          input_df=False, sparse=False))
